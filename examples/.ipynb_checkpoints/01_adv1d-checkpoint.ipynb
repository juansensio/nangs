# %%
# autoreload nangs
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# # One-dimensional Advection Equation

# %% [markdown]
# We want to solve the following PDE:
#
# \begin{equation}
#     \frac{\partial \phi}{\partial t} + u \frac{\partial \phi}{\partial x} = 0
# \end{equation}
#
# The independent variables (i.e, $x$ and $t$) are used as input values for the NN, and the solution (i.e. $\phi$) is the output. In order to find the solution, at each step the NN outputs are derived w.r.t the inputs. Then, a loss function that matches the PDE is built and the weights are updated accordingly. If the loss function goes to zero, we can assume that our NN is indeed the solution to our PDE. We will try to find a general solution for different values of $u$, so it will be set also as an input.

# %%
# imports
import numpy as np 
import matplotlib.pyplot as plt 
import nangs
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"

nangs.__version__, torch.__version__
# Out:
# ('0.1.1', '1.5.0')

# %% [markdown]
# To solve the PDE we first need a set of points to evaluate it, we will use this points as the dataset for training de NN.

# %%
# define the mesh

from nangs import Mesh

x = np.linspace(0,1,20)
t = np.linspace(0,1,30)
u = np.linspace(-1,1,10)

mesh = Mesh({'x': x, 't': t, 'u': u}, device=device)

# %% [markdown]
# Now we set the different boundary conditions

# %%
# initial condition (t = 0)

t0 = np.array([0])
_x, _t, _u = np.meshgrid(x, t0, u)
p0 = np.sin(2*np.pi*(_x- _u*_t))

# %%
plt.plot(x, p0[0,:,0])
plt.grid(True)
plt.xlabel('x')
plt.ylabel('$p_0$')
plt.show()

# %%
from nangs import Dirichlet, Periodic

# initial condition
initial_condition = Dirichlet({'x': x, 't': t0, 'u': u}, {'p': p0.reshape(-1)}, device=device)

# periodic bocos
x1 = np.array([0.])
x2 = np.array([1.])
periodic = Periodic({'x': x1, 't': t, 'u': u}, {'x': x2, 't': t, 'u': u}, device=device)

# %% [markdown]
# Then we define our Solver

# %%
from nangs import Solver

class MySolver(Solver):
    def computePDELoss(self, inputs, outputs):
        # compute gradients
        grads, = torch.autograd.grad(outputs, inputs,
                        grad_outputs=outputs.data.new(outputs.shape).fill_(1),
                        create_graph=True, only_inputs=True)
        # compute loss
        dpdx, dpdt = grads[:, 0], grads[:, 1]
        u = inputs[:, 2]
        pde = dpdt + u*dpdx
        return pde.pow(2).mean()

# %% [markdown]
# Now we can define a solution topology and solve the PDE.

# %%
from nangs import MLP

BATCH_SIZE = 256
LR = 1e-2
EPOCHS = 40
NUM_LAYERS = 3
NUM_HIDDEN = 128

mlp = MLP(len(mesh.vars), 1, NUM_LAYERS, NUM_HIDDEN).to(device)
optimizer = torch.optim.Adam(mlp.parameters())
criterion = torch.nn.MSELoss()
scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=LR, pct_start=0.1, total_steps=EPOCHS)

solver = MySolver()
solver.compile(mlp, optimizer, criterion, scheduler)
hist = solver.solve(mesh, bocos=[initial_condition, periodic], epochs=EPOCHS, batch_size=BATCH_SIZE)
# Out:
# Epoch 1/40  | lr 0.0004 | dirichlet 0.45493 | periodic 0.00436 | PDE 0.00148<p>Epoch 2/40  | lr 0.0028 | dirichlet 0.4311 | periodic 0.0086 | PDE 0.00551<p>Epoch 3/40  | lr 0.0076 | dirichlet 0.45019 | periodic 0.01521 | PDE 0.01026<p>Epoch 4/40  | lr 0.01 | dirichlet 0.39182 | periodic 0.01138 | PDE 0.01409<p>Epoch 5/40  | lr 0.00998 | dirichlet 0.40134 | periodic 0.02358 | PDE 0.03422<p>Epoch 6/40  | lr 0.00992 | dirichlet 0.29456 | periodic 0.01175 | PDE 0.05307<p>Epoch 7/40  | lr 0.00983 | dirichlet 0.19173 | periodic 0.00857 | PDE 0.0828<p>Epoch 8/40  | lr 0.0097 | dirichlet 0.14221 | periodic 0.01392 | PDE 0.0799<p>Epoch 9/40  | lr 0.00953 | dirichlet 0.07467 | periodic 0.02264 | PDE 0.064<p>Epoch 10/40  | lr 0.00933 | dirichlet 0.05636 | periodic 0.01386 | PDE 0.04471<p>Epoch 11/40  | lr 0.0091 | dirichlet 0.01899 | periodic 0.01265 | PDE 0.02404<p>Epoch 12/40  | lr 0.00883 | dirichlet 0.01015 | periodic 0.00628 | PDE 0.01522<p>Epoch 13/40  | lr 0.00854 | dirichlet 0.00693 | periodic 0.01284 | PDE 0.01255<p>Epoch 14/40  | lr 0.00821 | dirichlet 0.00885 | periodic 0.00477 | PDE 0.01428<p>Epoch 15/40  | lr 0.00787 | dirichlet 0.00299 | periodic 0.00229 | PDE 0.00733<p>Epoch 16/40  | lr 0.0075 | dirichlet 0.00181 | periodic 0.00187 | PDE 0.00423<p>Epoch 17/40  | lr 0.00711 | dirichlet 0.00101 | periodic 0.00083 | PDE 0.00292<p>Epoch 18/40  | lr 0.00671 | dirichlet 0.00072 | periodic 0.00061 | PDE 0.0022<p>Epoch 19/40  | lr 0.00629 | dirichlet 0.00058 | periodic 0.00066 | PDE 0.00184<p>Epoch 20/40  | lr 0.00587 | dirichlet 0.00047 | periodic 0.00054 | PDE 0.00165<p>Epoch 21/40  | lr 0.00544 | dirichlet 0.0004 | periodic 0.00035 | PDE 0.00136<p>Epoch 22/40  | lr 0.005 | dirichlet 0.00032 | periodic 0.00024 | PDE 0.00116<p>Epoch 23/40  | lr 0.00456 | dirichlet 0.00027 | periodic 0.00019 | PDE 0.0009<p>Epoch 24/40  | lr 0.00413 | dirichlet 0.00023 | periodic 0.00018 | PDE 0.00087<p>Epoch 25/40  | lr 0.00371 | dirichlet 0.00019 | periodic 0.00015 | PDE 0.00075<p>Epoch 26/40  | lr 0.00329 | dirichlet 0.00017 | periodic 0.00012 | PDE 0.0007<p>Epoch 27/40  | lr 0.00289 | dirichlet 0.00017 | periodic 0.00011 | PDE 0.00064<p>Epoch 28/40  | lr 0.0025 | dirichlet 0.00016 | periodic 0.0001 | PDE 0.00061<p>Epoch 29/40  | lr 0.00213 | dirichlet 0.00014 | periodic 9e-05 | PDE 0.00056<p>Epoch 30/40  | lr 0.00179 | dirichlet 0.00013 | periodic 8e-05 | PDE 0.00051<p>Epoch 31/40  | lr 0.00146 | dirichlet 0.00013 | periodic 7e-05 | PDE 0.00051<p>Epoch 32/40  | lr 0.00117 | dirichlet 0.00012 | periodic 7e-05 | PDE 0.00048<p>Epoch 33/40  | lr 0.0009 | dirichlet 0.00011 | periodic 7e-05 | PDE 0.00046<p>Epoch 34/40  | lr 0.00067 | dirichlet 0.00011 | periodic 6e-05 | PDE 0.00046<p>Epoch 35/40  | lr 0.00047 | dirichlet 0.00011 | periodic 6e-05 | PDE 0.00044<p>Epoch 36/40  | lr 0.0003 | dirichlet 0.00011 | periodic 6e-05 | PDE 0.00044<p>Epoch 37/40  | lr 0.00017 | dirichlet 0.0001 | periodic 6e-05 | PDE 0.00043<p>Epoch 38/40  | lr 8e-05 | dirichlet 0.0001 | periodic 5e-05 | PDE 0.00042<p>Epoch 39/40  | lr 2e-05 | dirichlet 0.0001 | periodic 5e-05 | PDE 0.00042<p>Epoch 40/40  | lr 0.0 | dirichlet 0.0001 | periodic 5e-05 | PDE 0.00042

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,5))
for name, vale in hist.items():
    if name is not 'lr':
        ax1.plot(hist[name], label=name)
ax1.grid(True)
ax1.legend()
ax1.set_yscale("log")
ax2.plot(hist['lr'], label='lr')
ax2.grid(True)
ax2.legend()
plt.show()

# %% [markdown]
# Finally we evaluate our solution on new points

# %%
from matplotlib import animation, rc
rc('animation', html='html5')

def update_plot(i, x, u, t, p):
    ax.clear()
    pe = np.sin(2.*np.pi*(x-u*t[i]))
    ax.plot(x, pe, label=f"exact (u = {U})")
    ax.plot(x, p[i], '.k', label="solution")
    ax.set_xlabel("x", fontsize=14)
    ax.set_ylabel("p", fontsize=14, rotation=np.pi/2)
    ax.legend(loc="upper right")
    ax.grid(True)
    ax.set_xlim([0, 1])
    ax.set_ylim([-1.2, 1.2])
    l2 = np.sqrt(np.sum((p[i]-pe)**2))
    ax.set_title(f"t = {t[i]:.3f} (L2 = {l2:.5f})")
    return ax

# %%
U = 0.5

x = np.linspace(0,1,30)
t = np.linspace(0,1,20)
u = np.array([U])
eval_mesh = Mesh({'x': x, 't': t, 'u': u}, device=device)

p = solver.eval(eval_mesh)
p = p.cpu().numpy().reshape(len(t), -1)

fig = plt.figure()
ax = plt.subplot(111)
anim = animation.FuncAnimation(fig, update_plot, frames=len(t), fargs=(x, U, t, p), interval=300)
plt.close()

# %%
anim
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...
